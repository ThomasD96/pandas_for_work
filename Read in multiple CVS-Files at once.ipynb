# %%
import pandas as pd
import glob
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\User\\Anaconda_Projects\\Data Analysis\\Read in similar CSV-files at once'

# %%
path = 'C:\\Users\\User\\Anaconda_Projects\\Data Analysis\\Read in similar CSV-files at once'
all_files = glob.glob(path + "/*.csv")

li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, skiprows=range(1,4), header=0)
    li.append(df)

frame = pd.concat(li, axis=0, ignore_index=True)

# %%
frame
# Out:
#     Symbol                  Company  Rank    Status        TRI   TB90   \
# 0      TCM   Thompson Creek Metals*     1       Buy  34542.6016   3.90
# 1       BB      BlackBerry Limited*     2       Buy  34542.6016   3.90
# 2      QUX       Quadra FNX Mining*     3       Buy  34542.6016   3.90
# 3      TRE       Sino-Forest Corp.*     4       Buy  34542.6016   3.90
# 4       VT             Viterra Inc.     5       Buy  34542.6016   3.90
# 5      LNR            Linamar Corp.     6       Buy  34542.6016   3.90
# 6      MDI  Major Drilling Grp Intl     7       Buy  34542.6016   3.90
# 7       ET      Evertz Technologies     8  Buy/Sell  34542.6016   3.90
# 8       SW   Sierra Wireless, Inc.*     9  Buy/Sell  34542.6016   3.90
# 9      NTR           Nutrien Ltd. *    10       Buy  34542.6016   3.90
# 10    OIL1            Oilexco Inc.*    11       Buy  34542.6016   3.90
# 11    VRS1      Allen-Vanguard Corp    12  Buy/Sell  34542.6016   3.90
# ...
